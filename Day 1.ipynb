# %% [markdown]
# Answer 1

# %%
RAINBOW

# %% [markdown]
# Answer 2

# %%
print("LETS UPGRADE")

# %% [markdown]
# Answer 3

# %%
cost_price=int(input())
selling_price=int(input())

if cost_price>selling_price:
  print("Loss")

elif cost_price<selling_price:
  print("Profit")

else:
  print("Neither")

# %% [markdown]
# Answer 4

# %%
rupee=int(input())
print(rupee*80)
